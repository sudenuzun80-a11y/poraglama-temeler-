# %% [markdown]
# <a href="https://colab.research.google.com/github/sudenuzun80-a11y/poraglama-temeler-/blob/main/scratchpad.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
A = 2020
print("yıl artık 2020")
#soru11
# Out:
# yıl artık 2020

# %%
vize = 50
final = 90
ortalama = (vize + final) / 2
print("Vize ve final notlarının ortalaması: {ortalama}")
#soru31
# Out:
# Vize ve final notlarının ortalaması: 70.0

# %%
sifre = "suden123!"
sonuc = sifre_guclugu_kontrol_et(sifre)
print(f"Şifre: '{sifre}'  {sonuc}")

zayif_sifre = "sifre"
sonuc_zayif = sifre_guclugu_kontrol_et(zayif_sifre)
print(f"Şifre: '{zayif_sifre}' -> {sonuc_zayif}")
#soru51
# Out:
# Şifre: 'suden123!'  Zayıf (Büyük harf içermeli)
# Şifre: 'sifre' -> Zayıf (En az 8 karakter olmalı)

# %%
def ters_liste_olustur(liste):
    return liste[::-1]

girdi_liste = [12, 70, 90]
ters_liste = ters_liste_olustur(girdi_liste)
print(f"Orijinal liste: {girdi_liste}")
print(f"Ters çevrilmiş liste: {ters_liste}")
#soru71
# Out:
# Orijinal liste: [12, 70, 90]
# Ters çevrilmiş liste: [90, 70, 12]

# %%
def carpim_tablosu(sayi):
    print(f"{sayi} için çarpım tablosu:")
    for i in range(1, 11):
        print(f"{sayi} x {i} = {sayi * i}")
girdi_sayi = 8
carpim_tablosu(girdi_sayi)
#soru91
# Out:
# 8 için çarpım tablosu:
# 8 x 1 = 8
# 8 x 2 = 16
# 8 x 3 = 24
# 8 x 4 = 32
# 8 x 5 = 40
# 8 x 6 = 48
# 8 x 7 = 56
# 8 x 8 = 64
# 8 x 9 = 72
# 8 x 10 = 80
